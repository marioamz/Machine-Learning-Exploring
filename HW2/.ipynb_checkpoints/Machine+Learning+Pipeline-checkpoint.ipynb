# %% [markdown]
# # Machine Learning Pipeline

# %% [markdown]
# This pipeline does the following:
#
# 1. Read / Load Data
# 2. Explore Data
# 3. Pre-Process and Clean Data
# 4. Generate Features / Predictors
# 5. Build Machine Learning Classifier
# 6. Evaluate Classifier

# %% [markdown]
# ## Read / Basic Clean / Explore

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.cross_validation import train_test_split

os.chdir('/Users/mariomoreno/Desktop/Grad School/Machine Learning/Week 2')

# %%
credit = pd.read_csv('credit-data.csv')

credit.rename(columns={"SeriousDlqin2yrs": "experienced_90days_delinquency", \
                    "NumberOfTime30-59DaysPastDueNotWorse": "times_30-59_pastdue", \
                    "DebtRatio": "debt_ratio", \
                    "MonthlyIncome": "monthly_income", \
                    "NumberOfOpenCreditLinesAndLoans": "times_open_credit_loans",\
                    "NumberOfTimes90DaysLate": "times_late", 
                    "NumberRealEstateLoansOrLines": "realestate_loans_lines", \
                    "NumberOfTime60-89DaysPastDueNotWorse": "times_60-89_pastdue",
                    "NumberOfDependents": "dependents",\
                    "RevolvingUtilizationOfUnsecuredLines": "use_unsecured_lines"
                    }, inplace = True)

# %%
nulls = credit.isnull().any()

credit['dependents'].fillna(0, inplace=True)
credit['monthly_income'].fillna(credit['monthly_income'].mean(), inplace=True)

# %% [markdown]
# Found the null values, which are in dependents and monthly_income. Since people who didn't report dependents are likely to not have any, filled them in with zeroes. Monthly income is different, imputed it as the mean of all the incomes. If I have time, I might explore K-Nearest Neighbor to take the monthly income of the neighbor most like our missing values.

# %%
credit.describe()
# Out:
#             PersonID  experienced_90days_delinquency  use_unsecured_lines  \
# count   41016.000000                    41016.000000          41016.00000
# mean   115800.154598                        0.161400              6.37587
# std     28112.723511                        0.367904            221.61895
# min        22.000000                        0.000000              0.00000
# 25%    106539.750000                        0.000000              0.03431
# 50%    119901.500000                        0.000000              0.18973
# 75%    134698.250000                        0.000000              0.66716
# max    149999.000000                        1.000000          22000.00000
#
#                 age       zipcode  times_30-59_pastdue     debt_ratio  \
# count  41016.000000  41016.000000         41016.000000   41016.000000
# mean      51.683489  60623.824166             0.589233     331.458137
# std       14.746880     11.984357             5.205628    1296.109695
# min       21.000000  60601.000000             0.000000       0.000000
# 25%       41.000000  60618.000000             0.000000       0.176375
# 50%       51.000000  60625.000000             0.000000       0.369736
# 75%       62.000000  60629.000000             0.000000       0.866471
# max      109.000000  60644.000000            98.000000  106885.000000
#
#        monthly_income  times_open_credit_loans    times_late  \
# count    4.101600e+04             41016.000000  41016.000000
# mean     6.578996e+03                 8.403477      0.419592
# std      1.206910e+04                 5.207324      5.190382
# min      0.000000e+00                 0.000000      0.000000
# 25%      3.800000e+03                 5.000000      0.000000
# 50%      6.418000e+03                 8.000000      0.000000
# 75%      7.245500e+03                11.000000      0.000000
# max      1.794060e+06                56.000000     98.000000
#
#        realestate_loans_lines  times_60-89_pastdue    dependents
# count            41016.000000         41016.000000  41016.000000
# mean                 1.008801             0.371587      0.753681
# std                  1.153826             5.169641      1.113639
# min                  0.000000             0.000000      0.000000
# 25%                  0.000000             0.000000      0.000000
# 50%                  1.000000             0.000000      0.000000
# 75%                  2.000000             0.000000      1.000000
# max                 32.000000            98.000000     13.000000

# %%
for i in credit:
    print()
    print(i, 'Summary Stats')
    print()
    print(credit[i].describe())
# Out:
# PersonID Summary Stats
#
# count     41016.000000
# mean     115800.154598
# std       28112.723511
# min          22.000000
# 25%      106539.750000
# 50%      119901.500000
# 75%      134698.250000
# max      149999.000000
# Name: PersonID, dtype: float64
#
# experienced_90days_delinquency Summary Stats
#
# count    41016.000000
# mean         0.161400
# std          0.367904
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: experienced_90days_delinquency, dtype: float64
#
# use_unsecured_lines Summary Stats
#
# count    41016.00000
# mean         6.37587
# std        221.61895
# min          0.00000
# 25%          0.03431
# 50%          0.18973
# 75%          0.66716
# max      22000.00000
# Name: use_unsecured_lines, dtype: float64
#
# age Summary Stats
#
# count    41016.000000
# mean        51.683489
# std         14.746880
# min         21.000000
# 25%         41.000000
# 50%         51.000000
# 75%         62.000000
# max        109.000000
# Name: age, dtype: float64
#
# zipcode Summary Stats
#
# count    41016.000000
# mean     60623.824166
# std         11.984357
# min      60601.000000
# 25%      60618.000000
# 50%      60625.000000
# 75%      60629.000000
# max      60644.000000
# Name: zipcode, dtype: float64
#
# times_30-59_pastdue Summary Stats
#
# count    41016.000000
# mean         0.589233
# std          5.205628
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max         98.000000
# Name: times_30-59_pastdue, dtype: float64
#
# debt_ratio Summary Stats
#
# count     41016.000000
# mean        331.458137
# std        1296.109695
# min           0.000000
# 25%           0.176375
# 50%           0.369736
# 75%           0.866471
# max      106885.000000
# Name: debt_ratio, dtype: float64
#
# monthly_income Summary Stats
#
# count    4.101600e+04
# mean     6.578996e+03
# std      1.206910e+04
# min      0.000000e+00
# 25%      3.800000e+03
# 50%      6.418000e+03
# 75%      7.245500e+03
# max      1.794060e+06
# Name: monthly_income, dtype: float64
#
# times_open_credit_loans Summary Stats
#
# count    41016.000000
# mean         8.403477
# std          5.207324
# min          0.000000
# 25%          5.000000
# 50%          8.000000
# 75%         11.000000
# max         56.000000
# Name: times_open_credit_loans, dtype: float64
#
# times_late Summary Stats
#
# count    41016.000000
# mean         0.419592
# std          5.190382
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max         98.000000
# Name: times_late, dtype: float64
#
# realestate_loans_lines Summary Stats
#
# count    41016.000000
# mean         1.008801
# std          1.153826
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          2.000000
# max         32.000000
# Name: realestate_loans_lines, dtype: float64
#
# times_60-89_pastdue Summary Stats
#
# count    41016.000000
# mean         0.371587
# std          5.169641
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max         98.000000
# Name: times_60-89_pastdue, dtype: float64
#
# dependents Summary Stats
#
# count    41016.000000
# mean         0.753681
# std          1.113639
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max         13.000000
# Name: dependents, dtype: float64

# %% [markdown]
# Might be worth dropping PersonID since it's random, might not have any impact on the final. A couple of points:
#
# 1) someone is 22,000 percent over their credit limit, which is ridiculous
# 2) someone's debt ratio is 106,885, which could be someone with no income
# 3) someone has more than 1 million in monthly income
# 4) someone has 32 real estate loans
# 5) someone has been 90 days late on payments 98 times
#
# Unclear if these are outliers or not, but I do plan to bin on monthly income, which should minimize the effect of the millionaire.

# %%
del credit['PersonID']

# %%
credit['experienced_90days_delinquency'].value_counts()
# Out:
# 0    34396
# 1     6620
# Name: experienced_90days_delinquency, dtype: int64

# %%
credit.hist(figsize=(20,20))
plt.show()

# %% [markdown]
# From these graphs, there's the potential for significant outliers in several different features. There might also be a need to discretize ages and monthly income.

# %%
correlations = []
    
for feature in credit:
    if feature != 'experienced_90days_delinquency':
        corr = credit['experienced_90days_delinquency'].astype('float64').corr(credit[feature].astype('float64'))
        correlations.append((feature, corr))

correlations
# Out:
# [('use_unsecured_lines', -0.0045861606035875165),
#  ('age', -0.17372784435590619),
#  ('zipcode', -0.045050979761833157),
#  ('times_30-59_pastdue', 0.14933355423396405),
#  ('debt_ratio', -0.013502206937829577),
#  ('monthly_income', -0.029876034939435268),
#  ('times_open_credit_loans', -0.039897662805912934),
#  ('times_late', 0.13960916523540789),
#  ('realestate_loans_lines', -0.010640862837506402),
#  ('times_60-89_pastdue', 0.121886468335426),
#  ('dependents', 0.066805785544506877)]

# %% [markdown]
# Taking a preliminary look at how correlated our independent variables might be with our dependent variable. Age is most significantly negatively correlated, while times 30-59 days past due is most significantly positively correlated. Neither variable is sufficiently correlated to suggest endogeneity.

# %%
for features in credit:
    print()
    print('Correlations for:', features)
    print()
    print(credit.corr().unstack()[features])
    print()
# Out:
# Correlations for: experienced_90days_delinquency
#
# experienced_90days_delinquency    1.000000
# use_unsecured_lines              -0.004586
# age                              -0.173728
# zipcode                          -0.045051
# times_30-59_pastdue               0.149334
# debt_ratio                       -0.013502
# monthly_income                   -0.029876
# times_open_credit_loans          -0.039898
# times_late                        0.139609
# realestate_loans_lines           -0.010641
# times_60-89_pastdue               0.121886
# dependents                        0.066806
# dtype: float64
#
#
# Correlations for: use_unsecured_lines
#
# experienced_90days_delinquency   -0.004586
# use_unsecured_lines               1.000000
# age                              -0.008003
# zipcode                           0.006009
# times_30-59_pastdue              -0.001999
# debt_ratio                        0.022250
# monthly_income                    0.005147
# times_open_credit_loans          -0.014590
# times_late                       -0.001686
# realestate_loans_lines            0.004763
# times_60-89_pastdue              -0.001413
# dependents                        0.005247
# dtype: float64
#
#
# Correlations for: age
#
# experienced_90days_delinquency   -0.173728
# use_unsecured_lines              -0.008003
# age                               1.000000
# zipcode                           0.005408
# times_30-59_pastdue              -0.068696
# debt_ratio                        0.038828
# monthly_income                    0.042148
# times_open_credit_loans           0.159866
# times_late                       -0.069036
# realestate_loans_lines            0.049168
# times_60-89_pastdue              -0.063622
# dependents                       -0.213304
# dtype: float64
#
#
# Correlations for: zipcode
#
# experienced_90days_delinquency   -0.045051
# use_unsecured_lines               0.006009
# age                               0.005408
# zipcode                           1.000000
# times_30-59_pastdue              -0.002424
# debt_ratio                        0.002088
# monthly_income                   -0.004471
# times_open_credit_loans          -0.009214
# times_late                       -0.001487
# realestate_loans_lines            0.003141
# times_60-89_pastdue              -0.001198
# dependents                       -0.001753
# dtype: float64
#
#
# Correlations for: times_30-59_pastdue
#
# experienced_90days_delinquency    0.149334
# use_unsecured_lines              -0.001999
# age                              -0.068696
# zipcode                          -0.002424
# times_30-59_pastdue               1.000000
# debt_ratio                       -0.011620
# monthly_income                   -0.011133
# times_open_credit_loans          -0.070704
# times_late                        0.984465
# realestate_loans_lines           -0.037863
# times_60-89_pastdue               0.988530
# dependents                       -0.009252
# dtype: float64
#
#
# Correlations for: debt_ratio
#
# experienced_90days_delinquency   -0.013502
# use_unsecured_lines               0.022250
# age                               0.038828
# zipcode                           0.002088
# times_30-59_pastdue              -0.011620
# debt_ratio                        1.000000
# monthly_income                   -0.008117
# times_open_credit_loans           0.082791
# times_late                       -0.014790
# realestate_loans_lines            0.177858
# times_60-89_pastdue              -0.013290
# dependents                       -0.072998
# dtype: float64
#
#
# Correlations for: monthly_income
#
# experienced_90days_delinquency   -0.029876
# use_unsecured_lines               0.005147
# age                               0.042148
# zipcode                          -0.004471
# times_30-59_pastdue              -0.011133
# debt_ratio                       -0.008117
# monthly_income                    1.000000
# times_open_credit_loans           0.096436
# times_late                       -0.013085
# realestate_loans_lines            0.116333
# times_60-89_pastdue              -0.011152
# dependents                        0.056253
# dtype: float64
#
#
# Correlations for: times_open_credit_loans
#
# experienced_90days_delinquency   -0.039898
# use_unsecured_lines              -0.014590
# age                               0.159866
# zipcode                          -0.009214
# times_30-59_pastdue              -0.070704
# debt_ratio                        0.082791
# monthly_income                    0.096436
# times_open_credit_loans           1.000000
# times_late                       -0.098176
# realestate_loans_lines            0.442776
# times_60-89_pastdue              -0.087154
# dependents                        0.068469
# dtype: float64
#
#
# Correlations for: times_late
#
# experienced_90days_delinquency    0.139609
# use_unsecured_lines              -0.001686
# age                              -0.069036
# zipcode                          -0.001487
# times_30-59_pastdue               0.984465
# debt_ratio                       -0.014790
# monthly_income                   -0.013085
# times_open_credit_loans          -0.098176
# times_late                        1.000000
# realestate_loans_lines           -0.054661
# times_60-89_pastdue               0.992143
# dependents                       -0.017061
# dtype: float64
#
#
# Correlations for: realestate_loans_lines
#
# experienced_90days_delinquency   -0.010641
# use_unsecured_lines               0.004763
# age                               0.049168
# zipcode                           0.003141
# times_30-59_pastdue              -0.037863
# debt_ratio                        0.177858
# monthly_income                    0.116333
# times_open_credit_loans           0.442776
# times_late                       -0.054661
# realestate_loans_lines            1.000000
# times_60-89_pastdue              -0.047996
# dependents                        0.119444
# dtype: float64
#
#
# Correlations for: times_60-89_pastdue
#
# experienced_90days_delinquency    0.121886
# use_unsecured_lines              -0.001413
# age                              -0.063622
# zipcode                          -0.001198
# times_30-59_pastdue               0.988530
# debt_ratio                       -0.013290
# monthly_income                   -0.011152
# times_open_credit_loans          -0.087154
# times_late                        0.992143
# realestate_loans_lines           -0.047996
# times_60-89_pastdue               1.000000
# dependents                       -0.017850
# dtype: float64
#
#
# Correlations for: dependents
#
# experienced_90days_delinquency    0.066806
# use_unsecured_lines               0.005247
# age                              -0.213304
# zipcode                          -0.001753
# times_30-59_pastdue              -0.009252
# debt_ratio                       -0.072998
# monthly_income                    0.056253
# times_open_credit_loans           0.068469
# times_late                       -0.017061
# realestate_loans_lines            0.119444
# times_60-89_pastdue              -0.017850
# dependents                        1.000000
# dtype: float64

# %% [markdown]
# There is significant correlation between three variables: times_late is 0.99 correlated with times_60-89_pastdue and .98 correlated with times_30-59_pastdue. 60-89 pastdue and 30-59 pastdue have similar correlation rates with each other. I'll drop those two to reduce noise.

# %%
del credit['times_30-59_pastdue']
del credit['times_60-89_pastdue']

# %% [markdown]
# ## Graphing data

# %%
credit['age'].plot('hist', bins=77, figsize = (20, 10))
plt.show()

# %% [markdown]
# This distribution is a bit rocky, though it's important to note that there seems to be abnormal spikes in age at around each decade mark (30, 40, 50, etc...). I'll put a pin in that for future exploration. For now, I'll smooth out the distribution by discretizing.

# %%
credit['monthly_income'].value_counts()[:10].plot(kind='bar', figsize = (20, 10))
plt.show()

# %% [markdown]
# Definitely something strange happening with monthly_income, there might be too many differing values to get an accurate sense. Will discretize.

# %%
age_bins = range(0, 110, 10)
income_bins = range(0, 200000, 10000)

credit['age_groups'] = pd.cut(credit['age'], age_bins) 
credit['monthly_income_groups'] = pd.cut(credit['monthly_income'], income_bins)

# %%
credit['times_late_binary'] = (credit['times_late'] >= credit['times_late'].mean()).astype(int)
del credit['times_late']

# %%
credit['times_late_binary'].value_counts().plot('bar', figsize=(20, 10))
plt.show()

# %%
credit['zipcode'].value_counts()
# Out:
# 60625    12904
# 60629     6459
# 60601     6427
# 60637     6354
# 60618     6332
# 60644     2540
# Name: zipcode, dtype: int64

# %%
spms = credit[['experienced_90days_delinquency', 'zipcode']].groupby(['experienced_90days_delinquency', 'zipcode'])
spms.size().to_frame().reset_index()
to_graph = spms.size().to_frame().reset_index()
graph = to_graph.pivot_table(0, 'zipcode', 'experienced_90days_delinquency')
graph.plot.bar(figsize=(20, 10))
plt.show()

# %% [markdown]
# There's a significantly larger population for people both being delinqueny on their loans and not being delinquent on their loans at 60625. Since it's consistently larger across both, I'll take it as a function of just having a larger population and drop the variable.

# %%
del credit['zipcode']

# %%
plt.scatter(credit['debt_ratio'], credit['dependents'])
plt.show()

# %% [markdown]
# Fascinatingly, the more kids you have, the lower your debt ratio.

# %%
plt.scatter(credit['age'], credit['monthly_income'])
plt.show()

# %% [markdown]
# Not much to say here, other than the need to use the bins for both of these variables. I'll drop both age and monthly income shortly in favor of their bins

# %%
plt.scatter(credit['monthly_income'], credit['debt_ratio'])
plt.show()

# %% [markdown]
# Pretty standard result here, the lower your income the higher your debt ratio.

# %%
plt.scatter(credit['monthly_income'], credit['dependents'])
plt.show()

# %% [markdown]
# Weird result in the sense that it contradicts previous results. The more kids you have, the lower your debt ratio according to an earlier graph. The lower your income, the higher your debt ration according to the previous graph. Yet, here, the lower your income, the more dependents you have. Putting a pin in this one, not sure how to interpret yet.

# %%
credit[['monthly_income_groups','dependents']].groupby('monthly_income_groups').mean().plot(figsize=(20,10))
plt.show()

# %% [markdown]
# With discretized values, we get a better sense of how dependents are distributed across the income groups.

# %%
credit[['monthly_income_groups','experienced_90days_delinquency']].groupby('monthly_income_groups').mean().plot(figsize=(20,10))
plt.show()

# %% [markdown]
# Two significant spikes in delinquency at 70k and 100k, the first of which is likely due to imputation techinques

# %%
credit[['age_groups','experienced_90days_delinquency']].groupby('age_groups').mean().plot(figsize=(20,10))
plt.show()

# %% [markdown]
# Delinquency declines with age.

# %% [markdown]
# After removing several variables due to multicollinearity, no potential explanatory power, or by nature of discretizing it, I've arrived at the features I'll be using.

# %%
del credit['age_groups']
del credit['monthly_income_groups']

# %% [markdown]
# ## Split data

# %%
credit['experienced_90days_delinquency'] = credit['experienced_90days_delinquency'].astype('bool')
credit['experienced_90days_delinquency'].value_counts()
# Out:
# False    34396
# True      6620
# Name: experienced_90days_delinquency, dtype: int64

# %%
dependent = pd.DataFrame(credit['experienced_90days_delinquency'])
del credit['experienced_90days_delinquency']
test_size = 0.4
x_train, x_test, y_train, y_test = train_test_split(credit, dependent, test_size=test_size)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (24609, 8)
# (16407, 8)
# (24609, 1)
# (16407, 1)

# %% [markdown]
# Split training and test data, checked to make sure they were the right size

# %% [markdown]
# ## K-Nearest Neighbor

# %%
metrics = ['euclidean', 'manhattan', 'chebyshev', 'minkowski']
weights = ['uniform', 'distance']

for k in range(10):
    for metric in metrics:
        for weight in weights:
            knn_loop = KNeighborsClassifier(n_neighbors=(k + 1), weights=weight, metric=metric)
            knn_loop.fit(x_train, y_train)
            results = knn_loop.predict(x_test)
            
            count = 0
            ordered_test_list = []

            for value in y_test:
                ordered_test_list.append(value)

            for x in range(len(ordered_test_list)):
                if ordered_test_list[x] == results[x]:
                    count += 1
# Out:
# /Users/mariomoreno/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
